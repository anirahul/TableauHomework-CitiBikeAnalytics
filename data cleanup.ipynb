# %%
#clean up and combine work books into on for Q1 of 2019
import glob
import pandas as pd

# %%
rider = pd.concat([pd.read_csv(f) for f in glob.glob('/Users/anirbanmukherjee/Desktop/Anaconda/TableauHomewor-CitiBikeAnalytics/Data/rider/*.csv')], ignore_index = True)
trip = pd.concat([pd.read_csv(f) for f in glob.glob('/Users/anirbanmukherjee/Desktop/Anaconda/TableauHomewor-CitiBikeAnalytics/Data/trip/*.csv')], ignore_index = True)
# Out:
# /Users/anirbanmukherjee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
rider.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
trip.head()
# Out:
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             1466
# 1                                             1483
# 2                                             3013
# 3                                             2633
# 4                                              812
#
#    3-Day Passes Purchased (midnight to 11:59 pm)   Column 1    Date  \
# 0                                             76  undefined  4/1/19
# 1                                             73  undefined  4/2/19
# 2                                             79  undefined  4/3/19
# 3                                             87  undefined  4/4/19
# 4                                             46  undefined  4/5/19
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
# 3                                       104268
# ...

# %%
rider.count()
# Out:
# tripduration               7978223
# starttime                  7978223
# stoptime                   7978223
# start station id           7978186
# start station name         7978186
# start station latitude     7978223
# start station longitude    7978223
# end station id             7978186
# end station name           7978186
# end station latitude       7978223
# end station longitude      7978223
# bikeid                     7978223
# usertype                   7978223
# birth year                 7978223
# gender                     7978223
# dtype: int64

# %%
clean_rider = rider.dropna(axis=0, how='any')

# %%
clean_rider.count()
# Out:
# tripduration               7978186
# starttime                  7978186
# stoptime                   7978186
# start station id           7978186
# start station name         7978186
# start station latitude     7978186
# start station longitude    7978186
# end station id             7978186
# end station name           7978186
# end station latitude       7978186
# end station longitude      7978186
# bikeid                     7978186
# usertype                   7978186
# birth year                 7978186
# gender                     7978186
# dtype: int64

# %%
trip.count()
# Out:
# 24-Hour Passes Purchased (midnight to 11:59 pm)       161
# 3-Day Passes Purchased (midnight to 11:59 pm)         161
# Column 1                                               71
# Date                                                  161
# Miles traveled today (midnight to 11:59 pm)           161
# Total Annual Members (All Time)                       161
# Trips over the past 24-hours (midnight to 11:59pm)    161
# dtype: int64

# %%
trip.head()
# Out:
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             1466
# 1                                             1483
# 2                                             3013
# 3                                             2633
# 4                                              812
#
#    3-Day Passes Purchased (midnight to 11:59 pm)   Column 1    Date  \
# 0                                             76  undefined  4/1/19
# 1                                             73  undefined  4/2/19
# 2                                             79  undefined  4/3/19
# 3                                             87  undefined  4/4/19
# 4                                             46  undefined  4/5/19
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
# 3                                       104268
# ...

# %%
clean_trip = trip.dropna(axis=1, how='any')

# %%
clean_trip.count()
# Out:
# 24-Hour Passes Purchased (midnight to 11:59 pm)       161
# 3-Day Passes Purchased (midnight to 11:59 pm)         161
# Date                                                  161
# Miles traveled today (midnight to 11:59 pm)           161
# Total Annual Members (All Time)                       161
# Trips over the past 24-hours (midnight to 11:59pm)    161
# dtype: int64

# %%
clean_trip.head()
# Out:
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             1466
# 1                                             1483
# 2                                             3013
# 3                                             2633
# 4                                              812
#
#    3-Day Passes Purchased (midnight to 11:59 pm)    Date  \
# 0                                             76  4/1/19
# 1                                             73  4/2/19
# 2                                             79  4/3/19
# 3                                             87  4/4/19
# 4                                             46  4/5/19
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
# 3                                       104268
# 4                                        46930
#
# ...

# %%
clean_rider.to_csv("/Users/anirbanmukherjee/Desktop/Anaconda/TableauHomewor-CitiBikeAnalytics/Data/rider_Q1_2019.csv")
clean_trip.to_csv("/Users/anirbanmukherjee/Desktop/Anaconda/TableauHomewor-CitiBikeAnalytics/Data/trip_Q1_2019.csv")
